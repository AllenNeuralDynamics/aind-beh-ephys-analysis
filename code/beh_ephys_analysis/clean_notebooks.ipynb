# %%
import json
from pathlib import Path

src = Path("/root/capsule/code/beh_ephys_analysis/session_combine/manscript_figures/F_waveform_space_tetrode.ipynb")
dst = Path("//root/capsule/code/beh_ephys_analysis/session_combine/manscript_figures/F_waveform_space_tetrode_fixed.ipynb")

nb = json.loads(src.read_text(encoding="utf-8", errors="replace"))

for c in nb.get("cells", []):
    if isinstance(c, dict) and "outputs" in c:
        c["outputs"] = []
    if isinstance(c, dict) and "execution_count" in c:
        c["execution_count"] = None

# keep backup next to original
src.with_suffix(".ipynb.bak").write_text(
    src.read_text(encoding="utf-8", errors="replace"),
    encoding="utf-8",
)

# write fixed notebook to new location
dst.parent.mkdir(parents=True, exist_ok=True)
dst.write_text(json.dumps(nb, ensure_ascii=False, indent=1), encoding="utf-8")

print(f"Done. Fixed notebook written to:\n  {dst}")
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# /root/capsule/code/beh_ephys_analysis/clean_notebooks.ipynb Cell 1 line 7
#       <a href='vscode-notebook-cell://codeocean.allenneuraldynamics.org/root/capsule/code/beh_ephys_analysis/clean_notebooks.ipynb#W0sdnNjb2RlLXJlbW90ZQ%3D%3D?line=3'>4</a> src = Path("/root/capsule/code/beh_ephys_analysis/session_combine/manscript_figures/F_waveform_space_tetrode.ipynb")
#       <a href='vscode-notebook-cell://codeocean.allenneuraldynamics.org/root/capsule/code/beh_ephys_analysis/clean_notebooks.ipynb#W0sdnNjb2RlLXJlbW90ZQ%3D%3D?line=4'>5</a> dst = Path("//root/capsule/code/beh_ephys_analysis/session_combine/manscript_figures/F_waveform_space_tetrode_fixed.ipynb")
# ...
