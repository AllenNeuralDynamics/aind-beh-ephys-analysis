# %%
import pickle
import pandas as pd
pd.set_option('display.max_columns', None)

# %%
pkl_path = r"/root/capsule/scratch/combined/combine_unit_tbl/combined_unit_tbl.pkl"

with open(pkl_path, "rb") as f:
    unit_tbl = pickle.load(f)

unit_tbl.head()
# Out:
#                                session  unit  qc_pass  opto_tagged  \
# 0  behavior_792292_2025-08-13_14-47-17    49     True        False
# 1  behavior_792292_2025-08-13_14-47-17    50     True        False
# 2  behavior_792292_2025-08-13_14-47-17    73     True        False
# 3  behavior_792292_2025-08-13_14-47-17    82     True        False
# 4  behavior_792292_2025-08-13_14-47-17   136     True        False
#
#    opto_tagging_pre  opto_tagging_post  anti  in_df  trial_count     p_max  \
# 0              True               True  True   True          282  0.319298
# 1              True               True  True   True          282  0.309539
# 2              True               True  True   True          282  0.308613
# 3              True               True  True   True          282  0.350310
# 4              True               True  True   True          282  0.309399
#
#    sig_counts    p_mean  lat_max_p  isi_violations       snr        eu  \
# ...

# %%
unit_tbl.columns
# Out:
# Index(['session', 'unit', 'qc_pass', 'opto_tagged', 'opto_tagging_pre',
#        'opto_tagging_post', 'anti', 'in_df', 'trial_count', 'p_max',
#        'sig_counts', 'p_mean', 'lat_max_p', 'isi_violations', 'snr', 'eu',
#        'corr', 'amp', 'amp_raw', 'peak', 'peak_raw', 'wf', 'wf_raw',
#        'wf_aligned', 'wf_2d', 'wf_2d_raw', 'probe', 'y_loc', 'rec_side', 'top',
#        'bottom', 'tag_loc', 'fr', 'decoder', 'all_p_max', 'all_p_mean',
#        'all_lat_max_p', 'all_corr', 'all_eu', 'all_sig_counts', 'x_ccf',
#        'y_ccf', 'z_ccf'],
#       dtype='object')

# %%
print("Total rows:", len(unit_tbl))

if "opto_tagged" in unit_tbl.columns:
    print("opto_tagged == True:", (unit_tbl["opto_tagged"] == True).sum())
else:
    print("Column 'opto_tagged' not found")
# Out:
# Total rows: 305
# opto_tagged == True: 77
